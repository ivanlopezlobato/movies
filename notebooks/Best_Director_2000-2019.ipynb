# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import pymysql
import getpass

# %matplotlib inline

# %% [markdown]
# Based on iMDB dataset (exported January 2020), find out the "best director" (highest avg. rating score) from the db

# %%
# I connect with a db locally
conn = pymysql.connect(host="localhost",
                       port=3306,
                       user="root",
                       passwd=getpass.getpass(),
                       db="movies")
# Out:
# ········

# %%
q = """
SELECT
    tp.nconst,                     
    count(*),
    AVG(averageRating) as rating,
    SUM(numVotes) as votes
FROM
    title_principals tp
JOIN
    title_basics tb
    ON tp.tconst = tb.tconst
JOIN
    title_ratings tr
    ON tp.tconst = tr.tconst
WHERE
    tp.category = "director"
    AND tb.titleType = "movie"
    AND tb.startYear BETWEEN 2000 AND 2019
GROUP BY
    tp.nconst
HAVING
    SUM(numVotes) > 100000
ORDER BY
    3
DESC
"""
# nconst is the unique identifier that imdb uses for identify people
# tconst is the unique identifier that imdb uses for identify movies
# we consider only movies between 2000 and 2019
# in this query we search for directors
# Minimum popularity required: threshold of at least 100.000 votes (in the sum of the whole movies in the timeframe)

# %%
# %time
directors = pd.read_sql(q,conn)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.01 µs

# %%
directors.describe().T
# Out:
#           count           mean            std         min       25%  \
# count(*)  890.0       5.338202       3.927521       1.000       3.0
# rating    890.0       6.515766       0.728162       3.075       6.1
# votes     890.0  532562.130337  754621.779930  100005.000  151483.0
#
#                     50%         75%         max
# count(*)       5.000000       7.000        51.0
# rating         6.566667       6.995         8.4
# votes     269894.500000  642321.750  11109933.0

# %% [markdown]
# - 890 directors has received (accumulative) more than 100.000 votes in iMDB for their movies
# - avg votes are 532.562, but the most popular has received over 11 Mio votes
# - max avg rating is 8.4 and min 3.075 in the dataset
# - more than the population has directed 5 movies or more. The max is 51(!) movies in 20 years

# %%
directors.head(20)
# Out:
#        nconst  count(*)    rating       votes
# 0   nm2937122         1  8.400000    321912.0
# 1   nm2130108         1  8.400000    297925.0
# 2   nm0745247         1  8.400000    297925.0
# 3   nm0634240         9  8.333333  11109933.0
# 4   nm0881279         4  8.200000   2716628.0
# 5   nm0677037         1  8.200000    883846.0
# 6   nm0215455         1  8.200000    568233.0
# 7   nm0386246         5  8.100000    616893.0
# 8   nm0254178         1  8.100000    156318.0
# 9   nm0594503         4  8.075000   1062877.0
# 10  nm0684342         1  8.000000    605678.0
# 11  nm0849164         1  8.000000    768342.0
# 12  nm0154716         2  8.000000    559393.0
# 13  nm1158544         1  8.000000    405059.0
# 14  nm0000233        10  7.960000   6085131.0
# 15  nm0001392         9  7.955556   6860242.0
# 16  nm0768959         2  7.950000    304841.0
# 17  nm0709056         2  7.850000    448224.0
# 18  nm0149196         5  7.840000    127596.0
# 19  nm0213450         5  7.820000   1178086.0

# %% [markdown]
# Challenges in the result:
# - we can't recognise the name of the director (nmXXXXXX)
# - top directors has directed only 1 movie (in 20 years), how to do a fair comparison?

# %%
# for retrieve the names, we will webscrap
import requests
import bs4

# %% [markdown]
# ---
# take one director as example

# %%
base = "https://www.imdb.com/name/"

code = "nm0634240"

# %%
url = base + code
r = requests.get(url)
soup = bs4.BeautifulSoup(r.content, "html.parser")

# %%
# movies = soup.find("div", class_="a-section imdb-scroll-table-inner").find_all("tr")
# movies[1].find("a", class_="a-link-normal").contents[0]
soup.title.contents[0]
# Out:
# 'Christopher Nolan - IMDb'

# %%
name = (soup.find("div", class_="name-overview-widget")
            .find("td", class_="name-overview-widget__section")
            .find("span", class_="itemprop")
            .contents[0])

# %%
name
# Out:
# 'Christopher Nolan'

# %% [markdown]
# ---
# create a function to retrieve the names
#
# initially create this function, working individually but is not for retrieve a series
#
# ```python
#
# def get_name(name_code):
#     # define url
#     base = "https://www.imdb.com/name/"
#     url = base + name_code
#
#     # get the soup
#     r = requests.get(url)
#     soup = bs4.BeautifulSoup(r.content, "html.parser")
#
#     # get name
#     return (soup.find("div", class_="name-overview-widget")
#                 .find("td", class_="name-overview-widget__section")
#                 .find("span", class_="itemprop")
#                 .contents[0])
# ```
#
#
# alternative solution

# %%
def get_name_title(name_code):
    # define url
    base = "https://www.imdb.com/name/"
    url = base + name_code
    
    # get the soup
    r = requests.get(url)
    soup = bs4.BeautifulSoup(r.content, "html.parser")
    
    # get name
    name = soup.title.contents[0]
    
    return name[:-7]

# %%
nconst_list = [n for n in directors.nconst]
get_name_title(nconst_list[0])
# Out:
# 'Adrian Molina'

# %%
list_of_names = [get_name_title(n) for n in nconst_list]

# %%
list_of_names
# Out:
# ['Adrian Molina',
#  'Bob Persichetti',
#  'Rodney Rothman',
#  'Christopher Nolan',
#  'Lee Unkrich',
#  'Bob Peterson',
#  'Ronnie Del Carmen',
#  'Rajkumar Hirani',
#  'Adam Elliot',
#  'Hayao Miyazaki',
#  'Jan Pinkava',
#  'Loveleen Tandan',
#  'Stephen Chbosky',
#  'Jared Bush',
#  'Quentin Tarantino',
#  'Peter Jackson',
#  'Dan Scanlon',
#  'Peter Ramsey',
#  'Nuri Bilge Ceylan',
#  'Dean DeBlois',
#  'Satoshi Kon',
#  'Josh Cooley',
#  'Martin McDonagh',
#  'Alfonso Cuarón',
#  'Mike Johnson',
#  'Jaco Van Dormael',
#  'Nathan Greno',
#  'Oriol Paulo',
#  'Greta Gerwig',
#  'Chris McKay',
#  'Martin Scorsese',
#  'Wes Anderson',
#  'Mel Gibson',
#  'David Silverman',
#  'Chris Sanders',
#  'Nitesh Tiwari',
#  'Pete Docter',
#  'David Fincher',
#  'Asghar Farhadi',
#  'Denis Villeneuve',
#  'Spike Jonze',
#  'Andrey Zvyagintsev',
#  'Alejandro G. Iñárritu',
#  'Andrew Stanton',
#  'Richard Curtis',
#  'Ted Demme',
#  'Eric Bress',
#  'J. Mackye Gruber',
#  'Alan Parker',
#  'Ben Affleck',
#  'Michael Gracey',
#  'Aneesh Chaganty',
#  'Rich Moore',
#  'Farhan Akhtar',
#  'Hong-jin Na',
#  'S.S. Rajamouli',
#  'Jean-Pierre Jeunet',
#  'Edgar Wright',
#  'Makoto Shinkai',
#  'Joss Whedon',
#  'Tom Ford',
#  'David Lynch',
#  'Taika Waititi',
#  'Don Hall',
#  'Derek Cianfrance',
#  'Stephen Daldry',
#  'Byron Howard',
#  'John Patrick Shanley',
#  'Theodore Melfi',
#  'Leigh Whannell',
#  'Brad Bird',
#  'Anton Corbijn',
#  'Damien Chazelle',
#  'Damián Szifron',
#  'Ryan Coogler',
#  'Chad Stahelski',
#  'Todd Field',
#  'Jean-Marc Vallée',
#  'Josh Boone',
#  'Charlie Kaufman',
#  'Steve McQueen',
#  'Matthew Vaughn',
#  'Sam Mendes',
#  'Sylvain Chomet',
#  'Neeraj Pandey',
#  'Anthony Russo',
#  'Joe Russo',
#  'Juan José Campanella',
#  'Steve Box',
#  'Nat Faxon',
#  'Jim Rash',
#  'Thea Sharrock',
#  'Aaron Sorkin',
#  'Vince Gilligan',
#  'Bong Joon Ho',
#  'Chris Williams',
#  'Paul Thomas Anderson',
#  'Danny Boyle',
#  'Jacques Audiard',
#  'Florian Henckel von Donnersmarck',
#  'J.J. Abrams',
#  'Peter Weir',
#  'Patty Jenkins',
#  'S. Shankar',
#  'Mamoru Hosoda',
#  'Paul Greengrass',
#  'James Mangold',
#  'Alex Garland',
#  'Robert Eggers',
#  'Jordan Peele',
#  'Ron Clements',
#  'John Musker',
#  'Darren Aronofsky',
#  'Andrew Dominik',
#  'James Cameron',
#  'Bennett Miller',
#  'Rian Johnson',
#  'John Hillcoat',
#  'Bruce A. Evans',
#  'Angus MacLane',
#  'Jennifer Lee',
#  'Travis Knight',
#  'Alper Caglar',
#  'Hirokazu Koreeda',
#  'David Yates',
#  'Amole Gupte',
#  'Matt Reeves',
#  'Mike Cahill',
#  'Chan-wook Park',
#  'Sriram Raghavan',
#  'Pedro Almodóvar',
#  'Ari Aster',
#  'Tom McCarthy',
#  'Kenneth Lonergan',
#  'Jonathan Dayton',
#  'Valerie Faris',
#  'Paul King',
#  'Christopher McQuarrie',
#  'Phil Lord',
#  'Christopher Miller',
#  'Simon Curtis',
#  'Mike Mills',
#  'Kevin Macdonald',
#  'Morten Tyldum',
#  'Steven Spielberg',
#  'José Padilha',
#  'Destin Daniel Cretton',
#  'Dan Trachtenberg',
#  'Michael Haneke',
#  'James Gunn',
#  'Hiromasa Yonebayashi',
#  'J.A. Bayona',
#  'Genndy Tartakovsky',
#  'Lars von Trier',
#  'Joseph Kosinski',
#  'Imtiaz Ali',
#  'Sidney Lumet',
#  'Tim Miller',
#  'Jean-Pierre Dardenne',
#  'Luc Dardenne',
#  'Ethan Coen',
#  'Julian Schnabel',
#  'Baz Luhrmann',
#  'Vishal Bhardwaj',
#  'Paolo Sorrentino',
#  'Roman Polanski',
#  'Joel Coen',
#  'Bryan Singer',
#  'Dexter Fletcher',
#  'Alejandro Amenábar',
#  'Jeff Nichols',
#  'Mike Leigh',
#  'Neill Blomkamp',
#  'Armando Iannucci',
#  'Joe Ranft',
#  'Shane Acker',
#  'Mark Andrews',
#  'Brenda Chapman',
#  'Steve Purcell',
#  'Alessandro Carloni',
#  'Christophe Lourdelet',
#  'Michael Showalter',
#  'Phil Johnston',
#  'Guillermo del Toro',
#  "Gavin O'Connor",
#  'Chris Buck',
#  'Anurag Kashyap',
#  'Giuseppe Tornatore',
#  'Clint Eastwood',
#  'Joe Berlinger',
#  'David Leitch',
#  'Edward Zwick',
#  'Barry Jenkins',
#  'Pierre Coffin',
#  'S. Craig Zahler',
#  'Ridley Scott',
#  'Alexander Payne',
#  'Andrew Adamson',
#  'George Tillman Jr.',
#  'Brian Percival',
#  'Drew Goddard',
#  'Jennifer Kent',
#  'A.R. Murugadoss',
#  'Todd Haynes',
#  'Lynne Ramsay',
#  'Stefano Sollima',
#  'Richard Linklater',
#  'Frank Oz',
#  'Andrew Douglas',
#  'Ömer Faruk Sorak',
#  'Scott Cooper',
#  'Ken Loach',
#  'Marc Webb',
#  'Paul Haggis',
#  'John Lee Hancock',
#  'Antoine Fuqua',
#  'Sanjay Leela Bhansali',
#  'George Lucas',
#  'Greg Berlanti',
#  'Frank Darabont',
#  'Neil Burger',
#  'Stephen J. Anderson',
#  'Robert Stromberg',
#  'Guy Ritchie',
#  'Kathryn Bigelow',
#  'Fatih Akin',
#  'Lee Toland Krieger',
#  'Olivier Nakache',
#  'Éric Toledano',
#  'Joe Wright',
#  'Jeff Tremaine',
#  'Kevin Reynolds',
#  'Garth Jennings',
#  'Ruben Östlund',
#  'Niki Caro',
#  'Roger Donaldson',
#  'Mark Romanek',
#  'Marjane Satrapi',
#  'Cary Joji Fukunaga',
#  'Adam McKay',
#  'Kar-Wai Wong',
#  'Shane Meadows',
#  'David Michôd',
#  'Jon S. Baird',
#  'Michaël R. Roskam',
#  'Asif Kapadia',
#  'Fernando Meirelles',
#  'Tom Tykwer',
#  'Mark Osborne',
#  'Zack Snyder',
#  'Debra Granik',
#  'Jason Reitman',
#  'Noah Baumbach',
#  'Marc Forster',
#  'Hans Petter Moland',
#  'Gore Verbinski',
#  'Francis Lawrence',
#  'Duncan Jones',
#  'Richard Ayoade',
#  'Jon Favreau',
#  'Gary Ross',
#  'R.J. Cutler',
#  'Ang Lee',
#  'Yimou Zhang',
#  'Ron Howard',
#  'Shane Black',
#  'Justin Chadwick',
#  'J.C. Chandor',
#  'Todd Phillips',
#  'Terry Zwigoff',
#  'Bernardo Bertolucci',
#  'Judd Apatow',
#  'Gareth Edwards',
#  'Robert Zemeckis',
#  'Ol Parker',
#  'James Wan',
#  'Craig Brewer',
#  'Jim Jarmusch',
#  'Sean Ellis',
#  'Peter Lord',
#  'Julie Taymor',
#  'Anthony Minghella',
#  'Roger Spottiswoode',
#  'Colin Trevorrow',
#  'Chris Butler',
#  'Matt Ross',
#  'Jordan Vogt-Roberts',
#  'Pawel Pawlikowski',
#  'Pablo Larraín',
#  'Nick Park',
#  'Cameron Crowe',
#  'Sean Baker',
#  'John Crowley',
#  'Ericson Core',
#  'Steve Martino',
#  'John Wells',
#  'John Michael McDonagh',
#  'Mike Newell',
#  'Jee-woon Kim',
#  'Greg Mottola',
#  'Richard LaGravenese',
#  'John Carney',
#  'Gregor Jordan',
#  'Tony Scott',
#  'Woody Allen',
#  'Doug Liman',
#  'Niels Arden Oplev',
#  'Glenn Ficarra',
#  'John Requa',
#  'Albert Hughes',
#  'Susanne Bier',
#  'Peter Sollett',
#  'Billy Ray',
#  'Peter Berg',
#  'George Miller',
#  'Allen Coulter',
#  'Zoya Akhtar',
#  'Nimród Antal',
#  'Curtis Hanson',
#  'Michel Gondry',
#  'Ruben Fleischer',
#  'Benny Safdie',
#  'Len Wiseman',
#  'Andrea Arnold',
#  'Carlos Saldanha',
#  'Michel Hazanavicius',
#  'Tim Burton',
#  'Davis Guggenheim',
#  'Joe Carnahan',
#  'Tom McGrath',
#  'Pierre Morel',
#  'Mark Pellington',
#  'Gus Van Sant',
#  'Gregory Hoblit',
#  'Wayne Kramer',
#  'Jonathan Hensleigh',
#  'Eric Darnell',
#  'Scott Frank',
#  'David Schwimmer',
#  'Ben Palmer',
#  'Nick Cassavetes',
#  'Peter Hedges',
#  'Stephen Frears',
#  'Josh Safdie',
#  'Rupert Wyatt',
#  'Lasse Hallström',
#  'Thomas Carter',
#  'Mimi Leder',
#  'Randall Wallace',
#  'Jon Watts',
#  'Saul Dibb',
#  'Thomas Vinterberg',
#  'Nancy Meyers',
#  'Rod Lurie',
#  'Richard Eyre',
#  'Walter Salles',
#  'Michael Dowse',
#  'Mira Nair',
#  'Gavin Hood',
#  'Nicolas Winding Refn',
#  'Gaspar Noé',
#  'François Ozon',
#  'Grant Heslov',
#  'Oliver Hirschbiegel',
#  'Joachim Rønning',
#  'David Ayer',
#  'Chris Renaud',
#  'Andy Muschietti',
#  'Sam Raimi',
#  'Alejandro Agresti',
#  'Jessie Nelson',
#  'John Maybury',
#  'Todd Strauss-Schulson',
#  'Clay Kaytis',
#  'Jake Schreier',
#  'Çagan Irmak',
#  'Ki-duk Kim',
#  'Paul McGuigan',
#  'David Frankel',
#  'Gary Fleder',
#  'David Mackenzie',
#  'Paul Verhoeven',
#  'Kenneth Branagh',
#  'Baltasar Kormákur',
#  'John Madden',
#  'Michael Hoffman',
#  'James Gray',
#  'Tim Johnson',
#  'Ben Younger',
#  'Ric Roman Waugh',
#  'David O. Russell',
#  'Lexi Alexander',
#  'Tony Gilroy',
#  'Jennifer Yuh Nelson',
#  'Dan Gilroy',
#  'Liam Lynch',
#  'Jon Hurwitz',
#  'Hayden Schlossberg',
#  'Daniel Scheinert',
#  'Wolfgang Becker',
#  'Craig Gillespie',
#  'Gabriele Muccino',
#  'Peter Webber',
#  'James Marsh',
#  'Mark Herman',
#  'Christophe Gans',
#  'Garth Davis',
#  'Tom Hooper',
#  'David F. Sandberg',
#  'Jay Russell',
#  'Brian Helgeland',
#  'Justin Lin',
#  'James Ponsoldt',
#  'Espen Sandberg',
#  'Neil Jordan',
#  'Álex de la Iglesia',
#  'F. Gary Gray',
#  'Jonas Åkerlund',
#  'Michael Apted',
#  'Mike Nichols',
#  'John Dahl',
#  'Abdellatif Kechiche',
#  'Alfonso Gomez-Rejon',
#  'David Mamet',
#  'John Lasseter',
#  'Jeff Schaffer',
#  'Alec Berg',
#  'David Mandel',
#  'Mike Binder',
#  'Patrick Tatopoulos',
#  'Ethan Maniquis',
#  'Adrian Grunberg',
#  'Eli Craig',
#  'Michael Sucsy',
#  'Jason Moore',
#  'Peter Landesman',
#  'Louis Leterrier',
#  'Phillip Noyce',
#  'Rob Marshall',
#  'John Curran',
#  'Jonathan Glazer',
#  'Brad Anderson',
#  'Sean Penn',
#  'Tony Goldwyn',
#  'Sam Fell',
#  'Ryan Fleck',
#  'Fede Alvarez',
#  'Jim Sheridan',
#  'David Twohy',
#  'Roger Michell',
#  'Ken Scott',
#  'Terry George',
#  'Steven Soderbergh',
#  'Scott Hicks',
#  'Jill Culton',
#  'Evan Goldberg',
#  'Stuart Hazeldine',
#  'Rakeysh Omprakash Mehra',
#  'Jay Roach',
#  'Chris Columbus',
#  'Michael Mann',
#  'Scott Derrickson',
#  'Nikolaj Arcel',
#  'Bibo Bergeron',
#  'Peyton Reed',
#  'Anand Tucker',
#  'David Robert Mitchell',
#  'Stephen Hopkins',
#  'Gurinder Chadha',
#  'Chris Wedge',
#  'Allen Hughes',
#  'Bobcat Goldthwait',
#  'Lana Wachowski',
#  'Lilly Wachowski',
#  'Michael Cuesta',
#  'Ashutosh Gowariker',
#  'Yorgos Lanthimos',
#  'Jean-François Richet',
#  'Robert Schwentke',
#  'Mark Dindal',
#  'Brett Ratner',
#  'Ronny Yu',
#  'James Watkins',
#  'John Francis Daley',
#  'Jonathan Goldstein',
#  'Martin Campbell',
#  'David Gordon Green',
#  'Werner Herzog',
#  'David Dobkin',
#  'Thor Freudenthal',
#  'Lone Scherfig',
#  'Lenny Abrahamson',
#  'Andrew Niccol',
#  'Thomas Bezucha',
#  'Andrew Davis',
#  'Asger Leth',
#  'Patrick Hughes',
#  'Rob Reiner',
#  'Conrad Vernon',
#  'Tarsem Singh',
#  'Alan Mak',
#  'Richard Glatzer',
#  'Lee Daniels',
#  'Anthony Stacchi',
#  'Gareth Evans',
#  'Sang-ho Yeon',
#  'Nicole Holofcener',
#  'Anna Boden',
#  'Juan Carlos Fresnadillo',
#  'Frank Miller',
#  'Ava DuVernay',
#  'Lorene Scafaria',
#  'Wes Ball',
#  'Sofia Coppola',
#  'P.J. Hogan',
#  'Paul Feig',
#  'Tate Taylor',
#  'Nigel Cole',
#  'David Cronenberg',
#  'Jerry Zucker',
#  'Warren Coleman',
#  'Judy Morris',
#  'Simon J. Smith',
#  'Phyllida Lloyd',
#  'Brad Furman',
#  'Matthew Robinson',
#  'Tommy Wirkola',
#  'Gary McKendry',
#  'Yarrow Cheney',
#  'Jean-Jacques Annaud',
#  'Wash Westmoreland',
#  'John Hamburg',
#  'Terrence Malick',
#  'Jonathan Levine',
#  'John Woo',
#  'Takashi Miike',
#  'Seth Gordon',
#  'Jonathan Demme',
#  'Jaume Collet-Serra',
#  'Jeremy Saulnier',
#  'Daniel Barnz',
#  'Olivier Assayas',
#  'Vicky Jenson',
#  'Lisa Cholodenko',
#  'Kyle Balda',
#  'Tomas Alfredson',
#  'Adam Brooks',
#  'Burr Steers',
#  'Dean Parisot',
#  'Mike Judge',
#  'Pete Travis',
#  'Nima Nourizadeh',
#  'Taylor Sheridan',
#  'Michael Winterbottom',
#  'Drake Doremus',
#  'Terry Gilliam',
#  'Jonathan Lynn',
#  'Kirsten Sheridan',
#  'Sharon Maguire',
#  'Richard Kelly',
#  'Robert Pulcini',
#  'Mikael Håfström',
#  'Michael Dougherty',
#  'William Friedkin',
#  'David Koepp',
#  'Kirk Jones',
#  'Alan Taylor',
#  'Bill Condon',
#  'Florent-Emilio Siri',
#  'Christopher Smith',
#  'David Lowery',
#  'John Erick Dowdle',
#  'Ben Wheatley',
#  'Luc Besson',
#  'Michael Bay',
#  'Jon Turteltaub',
#  'Tom Shadyac',
#  'Jim Field Smith',
#  'David Soren',
#  'Karey Kirkpatrick',
#  'Richard Loncraine',
#  'Chris Miller',
#  'James McTeigue',
#  'John Stevenson',
#  'Will Gluck',
#  'Sean Anders',
#  'Joe Cornish',
#  'Wally Pfister',
#  'Eric Guillon',
#  'Hany Abu-Assad',
#  'Atom Egoyan',
#  'Jake Kasdan',
#  'Boaz Yakin',
#  'Taylor Hackford',
#  'Joel Schumacher',
#  'Mike Thurmeier',
#  'Larry Charles',
#  'Karan Johar',
#  'Måns Mårlind',
#  'Björn Stein',
#  'Jay Duplass',
#  'Alexandre Aja',
#  'Wolfgang Petersen',
#  'Stephen Sommers',
#  'George Nolfi',
#  'Alex Kurtzman',
#  'Rawson Marshall Thurber',
#  'James Bobin',
#  'Mark Mylod',
#  'Scott Waugh',
#  'Gabor Csupo',
#  'Rodrigo Cortés',
#  'Justin Kurzel',
#  'Sergei Bodrov',
#  'Kelly Asbury',
#  'Richard Shepard',
#  'Lee Tamahori',
#  'Wilson Yip',
#  'Mike Flanagan',
#  'Henry Selick',
#  'Robert Altman',
#  'Iain Softley',
#  'Alexander Witt',
#  'Gregg Araki',
#  'Joshua Michael Stern',
#  'Akiva Schaffer',
#  'Matthijs van Heijningen Jr.',
#  'Carl Rinsch',
#  'Steven Knight',
#  'Jim Mickle',
#  'Rupert Sanders',
#  'Chris Weitz',
#  'Neil Marshall',
#  "Tommy O'Haver",
#  'Roar Uthaug',
#  'Jonathan Mostow',
#  'Mary Harron',
#  'Ari Sandel',
#  'Spike Lee',
#  'Stephen Gaghan',
#  'Breck Eisner',
#  'Kabir Khan',
#  'Kinji Fukasaku',
#  'Alex Proyas',
#  'Kimberly Peirce',
#  'Noam Murro',
#  'Dean Israelite',
#  'Daniel Espinosa',
#  'Nicholas Stoller',
#  'Ariel Vromen',
#  'Brad Silberling',
#  'Catherine Hardwicke',
#  'Shawn Levy',
#  'Dennis Gansel',
#  'Tim Story',
#  'D.J. Caruso',
#  'Anurag Basu',
#  'Priyadarshan',
#  'Anne Fletcher',
#  'Christian Ditter',
#  'Peter Farrelly',
#  'Roland Emmerich',
#  'Joe Johnston',
#  'Steven Shainberg',
#  'Michael Spierig',
#  'Peter Spierig',
#  'Marcus Dunstan',
#  'Jon Amiel',
#  'Richard Donner',
#  'Russell Mulcahy',
#  'Pascal Laugier',
#  'Steve Hickner',
#  'Bradford Lewis',
#  'Mathieu Kassovitz',
#  'Vincenzo Natali',
#  'Ryûhei Kitamura',
#  'Luca Guadagnino',
#  'Peter Segal',
#  'Mark Waters',
#  'Jesse Dylan',
#  'Josh Gordon',
#  'Will Speck',
#  'Barry Sonnenfeld',
#  'Phil Alden Robinson',
#  'André Øvredal',
#  'David Wain',
#  'Ivan Reitman',
#  'Christian Alvart',
#  'Rob Letterman',
#  'Rob Minkoff',
#  'Clark Johnson',
#  'David Slade',
#  'David Bruckner',
#  'John Singleton',
#  'Miguel Arteta',
#  'M. Night Shyamalan',
#  'Howard Deutch',
#  'Jared Hess',
#  'David Bowers',
#  'Ken Kwapis',
#  'Steve Pink',
#  'Gil Kenan',
#  'Ryan Murphy',
#  'James DeMonaco',
#  'Adam Robitel',
#  'Paul Weitz',
#  'Wayne Wang',
#  'McG',
#  'Tom Vaughan',
#  'Jeff Wadlow',
#  'Dominic Sena',
#  'Andy Tennant',
#  'Marc Lawrence',
#  'Henry Joost',
#  'Kevin Lima',
#  'Greg McLean',
#  'J Blakeson',
#  'Luke Greenfield',
#  'Griffin Dunne',
#  'Olivier Dahan',
#  'Prachya Pinkaew',
#  'Stefan Ruzowitzky',
#  'Jesse Peretz',
#  'Jon Lucas',
#  'Scott Moore',
#  'Danny Leiner',
#  'Adam Shankman',
#  'Kurt Wimmer',
#  'Rob Zombie',
#  'Mike Mitchell',
#  'Beeban Kidron',
#  'James L. Brooks',
#  'Babak Najafi',
#  'Eli Roth',
#  'Angelina Jolie',
#  'Robert Luketic',
#  'Bobby Farrelly',
#  'Jon Avnet',
#  'Harald Zwart',
#  'Christopher Landon',
#  'Garry Marshall',
#  'Oliver Parker',
#  'Oliver Stone',
#  'Steven Quale',
#  'Harmony Korine',
#  'Kirk DeMicco',
#  'Dean Devlin',
#  'Gérard Krawczyk',
#  'Gary Winick',
#  'Paul W.S. Anderson',
#  'Michael Davis',
#  'Adam Green',
#  'Kevin Smith',
#  'Daniel Alfredson',
#  'Robert Rodriguez',
#  'Donald Petrie',
#  'Dan Mazer',
#  'Stephen Norrington',
#  'Raman Hui',
#  'Jimmy Hayward',
#  'Simon Kinberg',
#  'Barry Levinson',
#  'Olivier Megaton',
#  'Xavier Gens',
#  'Elliott Lester',
#  'Rohit Shetty',
#  'Harold Ramis',
#  'Darren Lynn Bousman',
#  'Karyn Kusama',
#  'Michael Lehmann',
#  'Sam Taylor-Johnson',
#  'M.J. Bassett',
#  'Jaume Balagueró',
#  'Malcolm D. Lee',
#  'Brian Taylor',
#  'John Luessenhop',
#  'Rob Schmidt',
#  'Scott Stewart',
#  'Frank Coraci',
#  'Peter Howitt',
#  'Andrew Lau',
#  'Walt Becker',
#  'Simon Wells',
#  'David S. Goyer',
#  'Nikkhil Advani',
#  'Kyle Newacheck',
#  'Gary Shore',
#  'John Moore',
#  'Peter Chelsom',
#  'Dito Montiel',
#  'Neil LaBute',
#  'Mark Neveldine',
#  'Paco Plaza',
#  'Julie Anne Robinson',
#  'Stuart Beattie',
#  'Josh Trank',
#  'Tyler Gillett',
#  'Ernie Barbarash',
#  'Jonathan Liebesman',
#  'Hideo Nakata',
#  'Sean McNamara',
#  'Nora Ephron',
#  'Richard Schenkman',
#  'Ariel Schulman',
#  'Andy Fickman',
#  'Wes Craven',
#  'Matt Bettinelli-Olpin',
#  'Brian De Palma',
#  'Steve Beck',
#  'Greg Tiernan',
#  'Kevin Greutert',
#  'Mark Steven Johnson',
#  'John Polson',
#  'Corey Yuen',
#  'Tom Dey',
#  'George A. Romero',
#  'Jan de Bont',
#  'Tod Williams',
#  'Peter Billingsley',
#  'Corin Hardy',
#  'Simon West',
#  'Dennis Dugan',
#  'Brad Peyton',
#  'Steven Brill',
#  'David Hackl',
#  'Renny Harlin',
#  'Rob Bowman',
#  'Danny Pang',
#  'Rob Cohen',
#  'Dennie Gordon',
#  'Timur Bekmambetov',
#  'John Stockwell',
#  'Joe Roth',
#  'Victor Salva',
#  'Steve Bendelack',
#  'Ti West',
#  'Keenen Ivory Wayans',
#  'J.B. Rogers',
#  'Michael Lembeck',
#  'James Foley',
#  'Marcus Nispel',
#  'Elizabeth Banks',
#  'Joel Zwick',
#  'Oxide Chun Pang',
#  'Chuck Russell',
#  'William Brent Bell',
#  'Farah Khan',
#  'Mark Rosman',
#  'Ali Abbas Zafar',
#  'Kátia Lund',
#  'Brian Robbins',
#  'Tim Hill',
#  'Oren Peli',
#  'Patrick Lussier',
#  'David R. Ellis',
#  'Bryan Bertino',
#  'James Wong',
#  'Eric Brevig',
#  'Takashi Shimizu',
#  'Steve Carr',
#  'Sylvain White',
#  'Andrzej Bartkowiak',
#  'Adam Wingard',
#  'Jon M. Chu',
#  'Stefen Fangmeier',
#  'David McNally',
#  'Michael Patrick King',
#  'Roger Kumble',
#  'Betty Thomas',
#  'John Whitesell',
#  'John R. Leonetti',
#  'Pitof',
#  'Etan Cohen',
#  'Raja Gosnell',
#  'Steven R. Monroe',
#  'Brian Levant',
#  'Fred Wolf',
#  'Peter Hewitt',
#  'Michael Tiddes',
#  'David Zucker',
#  'Colin Strause',
#  'Greg Strause',
#  'Tom Brady',
#  'Johannes Roberts',
#  'Uwe Boll',
#  'Lawrence Guterman',
#  'Tom Six',
#  'Togan Gökbakar',
#  'Aaron Seltzer',
#  'Jason Friedberg']

# %%
directors = directors.assign(name=list_of_names)

# %%
directors.rating = directors.rating.round(2)

# %%
directors.votes = directors.votes.astype(int)

# %%
directors.head(20)
# Out:
#        nconst  count(*)  rating     votes               name
# 0   nm2937122         1    8.40    321912      Adrian Molina
# 1   nm2130108         1    8.40    297925    Bob Persichetti
# 2   nm0745247         1    8.40    297925     Rodney Rothman
# 3   nm0634240         9    8.33  11109933  Christopher Nolan
# 4   nm0881279         4    8.20   2716628        Lee Unkrich
# 5   nm0677037         1    8.20    883846       Bob Peterson
# 6   nm0215455         1    8.20    568233  Ronnie Del Carmen
# 7   nm0386246         5    8.10    616893    Rajkumar Hirani
# 8   nm0254178         1    8.10    156318        Adam Elliot
# 9   nm0594503         4    8.07   1062877     Hayao Miyazaki
# 10  nm0684342         1    8.00    605678        Jan Pinkava
# 11  nm0849164         1    8.00    768342    Loveleen Tandan
# 12  nm0154716         2    8.00    559393    Stephen Chbosky
# 13  nm1158544         1    8.00    405059         Jared Bush
# 14  nm0000233        10    7.96   6085131  Quentin Tarantino
# 15  nm0001392         9    7.96   6860242      Peter Jackson
# 16  nm0768959         2    7.95    304841        Dan Scanlon
# 17  nm0709056         2    7.85    448224       Peter Ramsey
# 18  nm0149196         5    7.84    127596  Nuri Bilge Ceylan
# 19  nm0213450         5    7.82   1178086       Dean DeBlois

# %% [markdown]
# The list is not so obvious, the first positions are occupied by directors of animation movies (actually position 2 and 3 belong to the same movie, which was co-directed)
#
# Also found some of more iconic directors (Christopher Nolan (4), Quentin Tarantino(15) or Peter Jackson(16)

# %%
#directors.to_csv("../data/top_directors_imdb.csv", index=False)

# %% [markdown]
# to be continued
